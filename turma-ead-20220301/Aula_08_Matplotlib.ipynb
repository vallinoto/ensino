# %%
#!pip install matplotlib

# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %%
# comando abaixo serve para visualizar os graficos dentro da celula do notebook
# %matplotlib inline
#%matplotlib notebook

# %%
plt.style.use('ggplot')

# %%
# y = x²
x = [1,2,3,4]
y = [1,4,9,16]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('Nome do Eixo X')
plt.ylabel('Nome do Eixo Y')
plt.show()

# %%
plt.plot(x,y,'o--' )
plt.xlabel('Nome do Eixo X')
plt.ylabel('Nome do Eixo Y')
plt.show()

# %%
plt.plot(x,y,'o', linewidth=2, markersize=12 , linestyle='dashed', color='green' )
plt.xlabel('Nome do Eixo X')
plt.ylabel('Nome do Eixo Y')
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('Nome do Eixo X')
plt.ylabel('Nome do Eixo Y')
plt.axis([0,4,0,16])
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('Nome do Eixo X')
plt.ylabel('Nome do Eixo Y')
plt.xticks([0,2,4,6])
plt.yticks([-1,4,8,18])
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('Nome do Eixo X (Valores em R$)')
plt.ylabel('Nome do Eixo Y')
plt.title('Titulo do Gráfico - Comparacao entre X e Y')
plt.axis([0,4,0,16])
plt.show()

# %%
plt.plot(x,y, label='Dados coletado')
plt.xlabel('Nome do Eixo X (Valores em R$)')
plt.ylabel('Nome do Eixo Y')
plt.title('Titulo do Gráfico - Comparacao entre X e Y')
plt.legend( )
plt.axis([0,4,0,16])
plt.show()

# %%
plt.plot(x,y, label='Dados coletado')
plt.xlabel('Nome do Eixo X (Valores em R$)')
plt.ylabel('Nome do Eixo Y')
plt.title('Titulo do Gráfico - Comparacao entre X e Y')
plt.legend( )
plt.text(2.5,10, 'Aqui eu \ntenho \numa nota')
plt.axis([0,4,0,16])
plt.show()

# %%
plt.plot(x,y, label='Dados coletado')
plt.xlabel('Nome do Eixo X (Valores em R$)')
plt.ylabel('Nome do Eixo Y')
plt.title('Titulo do Gráfico - Comparacao entre X e Y')
plt.legend( )
plt.text(2.5,10, 'Aqui eu \ntenho \numa nota', fontsize=12)
plt.axis([0,4,0,16])
plt.show()

# %%
plt.plot(x,y, 'o', markersize=8, label='Dados coletado', color='#483D8B', lw=2, ls=':')
plt.xlabel('Nome do Eixo X (Valores em R$)')
plt.ylabel('Nome do Eixo Y')
plt.title('Titulo do Gráfico - Comparacao entre X e Y')
plt.legend( )
plt.text(2.5,10, 'Aqui eu \ntenho \numa nota', fontsize=12)
plt.axis([0,5,0,17])
plt.show()

# %%
lista_produtos = [  'martelo', 'prego', 'parafuso']
valor_produtos = [15,2,4]

# %%
plt.bar(lista_produtos, valor_produtos)
plt.show()

# %%
plt.bar(lista_produtos, valor_produtos, color='#345b70')
plt.title('Quantidade de Produtos')
plt.show()

# %%
import numpy as np

qtdA = [ 10, 36, 24, 8 ]
qtdB = [14,25,16,15]

trimestre = ['Trim 1','Trim 2','Trim 3','Trim 4']

# %%
plt.bar(np.arange(len(qtdA)), qtdA)
plt.bar([ x + 0.25 for x in range(len(qtdA))], qtdB)
plt.xticks([ x + 0.25 for x in range(len(qtdA))], trimestre)
# Out:
# ([<matplotlib.axis.XTick at 0x7fce035222d0>,
# ...
#  [Text(0, 0, 'Trim 1'),
#   Text(0, 0, 'Trim 2'),
#   Text(0, 0, 'Trim 3'),
#   Text(0, 0, 'Trim 4')])

# %%
plt.bar(np.arange(len(qtdA)), qtdA, width=0.25)
plt.bar([ x + 0.25 for x in range(len(qtdA))], qtdB, width=0.25)
plt.xticks([ x + 0.25 for x in range(len(qtdA))], trimestre)
plt.show()

# %%
trimestre =  ['Trimestre 1','Trimestre 2','Trimestre 3','Trimestre 4']

plt.bar(np.arange(len(qtdA)), qtdA, width=0.25)
plt.bar([ x + 0.25 for x in range(len(qtdA))], qtdB, width=0.25)
plt.xticks([ x + 0.25 for x in range(len(qtdA))], trimestre)
plt.xticks(rotation=45)
plt.legend(['Produto A','Produto B'])
plt.show()

# %%
plt.barh(lista_produtos, valor_produtos, color='#345b70')
plt.title('Quantidade de Produtos')
plt.show()

# %%
plt.scatter(x,y, marker='v')
plt.show()

# %%
plt.pie(valor_produtos, labels=lista_produtos)
plt.show()

# %%
plt.pie(valor_produtos, labels=lista_produtos, autopct='%1.2f%%', )
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.pie(valor_produtos, labels=valor_produtos, autopct='%1.2f%%', explode=(0,0.2,0), shadow=True)
plt.legend(lista_produtos)
plt.show()
